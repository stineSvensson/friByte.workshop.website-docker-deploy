# %% [markdown]
# # Oppgaver Uke 8

# %% [markdown]
# ## Oppgave 1

# %% [markdown]
# Finn determinanten til matrisene
# 1. $$\left[\begin{array}{cc} 2 & 3\\ 4 & 2\end{array}\right]$$
# 1. $$\left[\begin{array}{cc} -2 & 3\\ 4 & 2\end{array}\right]$$

# %% [markdown]
# ## Oppgave 2

# %% [markdown]
# Løs både for hånd og ved help av python
#
# 1. MIP 10.6.5
# 2. MIP 10.6.6
# 3. MIP 10.5.2
# 4. MIP 10.5.9

# %% [markdown]
# ## Oppgave 3

# %% [markdown]
# Fullfør følgende python funksjoner:

# %%
import numpy as np

def determinant2x2(A):
    """
    Begregner determinanten til en 2 x 2 matrise

    Parametere:
        A (np.ndarray): En Numpy-array med to rader og to kolonner

    Returnerer:
        float: Determinanten til matrisen A.
    """
    a = A[0, 0]             #henter verdiene til matrisen, og finner hva som er hva
    b = A[0, 1]
    c = A[1, 0]
    d = A[1, 1]
    return (a*d)-(b*c)
A = np.array([[3,4],
             [4,5]])
print(A)


def determinant3x3(A):
    """
    Begregner determinanten til en 3 x 3 matrise

    Parametere:
        A (np.ndarray): En Numpy-array med tre rader og tre kolonner

    Returnerer:
        float: Determinanten til matrisen A.
    """
    a = A[0, 0]
    b = A[0, 1]
    c = A[0, 2]
    return a * determinant2x2(A[1:, [1, 2]]) - determinant2x2(A[1:, [0, 2]]) + determinant2x2(A[1:, ])# + fortsett her
# Out:
# [[3 4]
#  [4 5]]

# %%
import numpy as np

def determinant2x2(A):
    """
    Beregner determinanten til en 2 x 2 matrise

    Parametere:
        A (np.ndarray): En Numpy-array med to rader og to kolonner

    Returnerer:
        float: Determinanten til matrisen A.
    """
    a = A[0, 0]
    b = A[0, 1]
    c = A[1, 0]
    d = A[1, 1]
    return (a * d) - (b * c)

def determinant3x3(A):
    """
    Beregner determinanten til en 3 x 3 matrise

    Parametere:
        A (np.ndarray): En Numpy-array med tre rader og tre kolonner

    Returnerer:
        float: Determinanten til matrisen A.
    """
    a = A[0, 0]
    b = A[0, 1]
    c = A[0, 2]

    # Beregner determinantene til de 2x2 delmatrisene
    det1 = determinant2x2(A[1:, [1, 2]])  # Minor for 'a'
    det2 = determinant2x2(A[1:, [0, 2]])  # Minor for 'b'
    det3 = determinant2x2(A[1:, [0, 1]])  # Minor for 'c'

    return a * det1 - b * det2 + c * det3

# Test 3x3 determinant
A = np.array([[3, 4, 2],
              [1, 5, 7],
              [6, 8, 9]])

print("3x3 determinant:", determinant3x3(A))

# %% [markdown]
# Hvis du synes dette er enkelt, se om du kan skrive kode som beregner determinanten til 4 x 4 matriser.

# %% [markdown]
# Bruk funksjonene to å løse oppgavene 10.6.1 og 10.6.2 i MIP.

# %% [markdown]
# ## Oppgave 4

# %% [markdown]
# Løs MIP oppgave 10.5.8 for hånd. Skriv deretter en Python-funksjon som returnerer en m x n matrise etter samme formel som i oppgaven.

# %% [markdown]
# ## Oppgave 5

# %% [markdown]
# Løs oppgavene
#
# 1. MIP 10.6.7
# 2. MIP 10.6.8
# 3. MIP 10.7.1
# 4. MIP 10.7.4
# 5. MIP 10.7.7

# %% [markdown]
# ## Oppgave 6

# %% [markdown]
# Fullfør følgende python funksjon ved hjelp av formelen i oppgave MIP 10.7.4. Bruk funksjonen til å løse oppgave 10.7.5 i MIP.

# %%
import numpy as np

def invers2x2(A):
    """
    Begregner den inverse matrisen til en 2 x 2 matrise
    Hvis den inverse matrisen ikke finnes stopper funksjonen opp
    med en feilmelding

    Parametere:
        A (np.ndarray): En Numpy-array med to rader og to kolonner

    Returnerer:
        A_invers (np.ndarray): En Numpy-array med to rader og to kolonner
    """
    d = determinant2x2(A)
    assert d != 0, 'Determinanten er null, så den inverse matrisen finnes ikke'

    p = A[0, 0]
    q = A[0, 1]
    r = A[1, 0]
    s = A[1, 1]

    a = s/d
    # b =
    # c =
    # d =

    # A_invers = np.array([
    #  [a, b],
    #  [c, d]
    # ])
    return # A_invers

# %% [markdown]
# ## Oppgave 7

# %% [markdown]
# Gjør [quiz med spørsmål fra eksamen i fjor.](https://mitt.uib.no/courses/50911/quizzes/48577)
